# %% [markdown]
# #### Pandas Dataframe by Database
#
# ##### DB 모듈
# - MySQL : pymysql
# - Oracle : cx_Oracle
# - SQL server : pymssql

# %%
# MySQL
# !pip install pymysql
# Out:
# ...
#                                               0.0/43.7 kB ? eta -:--:--
#      ---------------------------------------- 43.7/43.7 kB 2.2 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import pymysql

# %%
conn = pymysql.connect(host='210.119.14.56', port=3306, user='root', password='12345', db='sakila')
query = 'SELECT * FROM actor'

df =pd.read_sql_query(query, conn)
print('조회 완료')
# Out:
# 조회 완료
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_7764\2495762381.py:4: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df =pd.read_sql_query(query, conn)

# %%
df
# Out:
#      actor_id first_name     last_name         last_update
# 0           1   PENELOPE       GUINESS 2006-02-15 04:34:33
# 1           2       NICK      WAHLBERG 2006-02-15 04:34:33
# 2           3         ED         CHASE 2006-02-15 04:34:33
# 3           4   JENNIFER         DAVIS 2006-02-15 04:34:33
# 4           5     JOHNNY  LOLLOBRIGIDA 2006-02-15 04:34:33
# ..        ...        ...           ...                 ...
# 195       196       BELA        WALKEN 2006-02-15 04:34:33
# 196       197      REESE          WEST 2006-02-15 04:34:33
# 197       198       MARY        KEITEL 2006-02-15 04:34:33
# 198       199      JULIA       FAWCETT 2006-02-15 04:34:33
# 199       200      THORA        TEMPLE 2006-02-15 04:34:33
#
# [200 rows x 4 columns]

# %%
df.to_csv('./actor_list.csv', encoding='utf-8', index=False)

# %%
titanic = pd.read_csv('./data/titanic_train.csv')
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# jinja2 설치
# !pip install Jinja2
# Out:
# ...
#                                               0.0/133.1 kB ? eta -:--:--
#      -------------------------------------- 133.1/133.1 kB 4.0 MB/s eta 0:00:00
# ...

# %%
titanic_train2 = titanic[['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']]
titanic_train2
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0              1         0       3  22.0      1      0   7.2500
# 1              2         1       1  38.0      1      0  71.2833
# 2              3         1       3  26.0      0      0   7.9250
# 3              4         1       1  35.0      1      0  53.1000
# 4              5         0       3  35.0      0      0   8.0500
# ..           ...       ...     ...   ...    ...    ...      ...
# 886          887         0       2  27.0      0      0  13.0000
# 887          888         1       1  19.0      0      0  30.0000
# 888          889         0       3   NaN      1      2  23.4500
# 889          890         1       1  26.0      0      0  30.0000
# 890          891         0       3  32.0      0      0   7.7500
#
# [891 rows x 7 columns]

# %%
pd.options.display.max_rows = 100 # 최대 행수를 100개 지정
titanic_train2.head(100).style.highlight_max(color='lightgreen')
# Out:
# <style type="text/css">
# ...

# %%
titanic_train2.head(100).style.highlight_min(color='orange')
# Out:
# <style type="text/css">
# ...

# %%
titanic_train2.head(100).style.highlight_null(color='lightgray')
# Out:
# <style type="text/css">
# #T_7b265_row5_col3, #T_7b265_row17_col3, #T_7b265_row19_col3, #T_7b265_row26_col3, #T_7b265_row28_col3, #T_7b265_row29_col3, #T_7b265_row31_col3, #T_7b265_row32_col3, #T_7b265_row36_col3, #T_7b265_row42_col3, #T_7b265_row45_col3, #T_7b265_row46_col3, #T_7b265_row47_col3, #T_7b265_row48_col3, #T_7b265_row55_col3, #T_7b265_row64_col3, #T_7b265_row65_col3, #T_7b265_row76_col3, #T_7b265_row77_col3, #T_7b265_row82_col3, #T_7b265_row87_col3, #T_7b265_row95_col3 {
#   background-color: lightgray;
# }
# </style>
# <table id="T_7b265">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7b265_level0_col0" class="col_heading level0 col0" >PassengerId</th>
#       <th id="T_7b265_level0_col1" class="col_heading level0 col1" >Survived</th>
#       <th id="T_7b265_level0_col2" class="col_heading level0 col2" >Pclass</th>
#       <th id="T_7b265_level0_col3" class="col_heading level0 col3" >Age</th>
# ...

# %%
# !pip install matplotlib
# Out:
# ...
#                                               0.0/7.6 MB ? eta -:--:--
#      -                                        0.3/7.6 MB 6.8 MB/s eta 0:00:02
#      ----                                     0.8/7.6 MB 8.7 MB/s eta 0:00:01
#      -------                                  1.4/7.6 MB 10.0 MB/s eta 0:00:01
#      -----------                              2.2/7.6 MB 12.6 MB/s eta 0:00:01
#      ---------------                          2.9/7.6 MB 12.5 MB/s eta 0:00:01
#      ----------------------                   4.4/7.6 MB 15.5 MB/s eta 0:00:01
#      -----------------------------------      6.7/7.6 MB 20.4 MB/s eta 0:00:01
#      ---------------------------------------  7.6/7.6 MB 22.1 MB/s eta 0:00:01
#      ---------------------------------------  7.6/7.6 MB 22.1 MB/s eta 0:00:01
#      ---------------------------------------- 7.6/7.6 MB 18.0 MB/s eta 0:00:00
# ...
#                                               0.0/470.9 kB ? eta -:--:--
# ...

# %%
# 출력포맷
titanic_train2.tail(20).style.format({'Fare' : '${:.2f}'})
# Out:
# <style type="text/css">
# </style>
# <table id="T_e6dea">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e6dea_level0_col0" class="col_heading level0 col0" >PassengerId</th>
#       <th id="T_e6dea_level0_col1" class="col_heading level0 col1" >Survived</th>
#       <th id="T_e6dea_level0_col2" class="col_heading level0 col2" >Pclass</th>
#       <th id="T_e6dea_level0_col3" class="col_heading level0 col3" >Age</th>
#       <th id="T_e6dea_level0_col4" class="col_heading level0 col4" >SibSp</th>
#       <th id="T_e6dea_level0_col5" class="col_heading level0 col5" >Parch</th>
#       <th id="T_e6dea_level0_col6" class="col_heading level0 col6" >Fare</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e6dea_level0_row0" class="row_heading level0 row0" >871</th>
#       <td id="T_e6dea_row0_col0" class="data row0 col0" >872</td>
#       <td id="T_e6dea_row0_col1" class="data row0 col1" >1</td>
# ...
