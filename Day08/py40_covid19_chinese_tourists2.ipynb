# %% [markdown]
# #### 코로나 바이러스 영향을 중국인 관광객 증감분석
#
# ##### 외국인 출입국 통계 데이터
#
# 한국관광 데이터랩 : https://datalab.visitkorea.or.kr/
# - 제공하는 csv파일을 추가작업으로 년월일 xlsx로 변경
#
#
# ##### 엑셀데이터 로드
# 기준 2019 1월 데이터

# %%
# openpyxl 모듈 설치
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\program files\python311\lib\site-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in c:\program files\python311\lib\site-packages (from openpyxl) (1.1.0)

# %%
# 데이터 분석용 모듈 임포트
import pandas as pd
import numpy as np

# %%
# 2019년 1월 엑셀데이터 로드
# 전년동기 ~ 구성비까지의 컬럼은 필요없음
# 행 전년동기 ~ 구성비까지 내용은 스킵
kto_201901 = pd.read_excel('./data/kto_201901.xlsx', header=1, usecols='A:G', skipfooter=4)

kto_201901
# Out:
#          국적      관광     상용    공용  유학/연수      기타       계
# 0      아시아주  765082  10837  1423  14087  125521  916950
# 1        일본  198805   2233   127    785    4576  206526
# 2        대만   86393     74    22    180    1285   87954
# 3        홍콩   34653     59     2     90    1092   35896
# 4       마카오    2506      2     0     17      45    2570
# ..      ...     ...    ...   ...    ...     ...     ...
# 62  아프리카 기타     768    718    90    206     908    2690
# 63     기타대륙      33      4     0      1      16      54
# 64     국적미상      33      4     0      1      16      54
# 65     교포소계       0      0     0      0   15526   15526
# 66       교포       0      0     0      0   15526   15526
#
# [67 rows x 7 columns]

# %%
kto_201901.tail()
# Out:
#          국적   관광   상용  공용  유학/연수     기타      계
# 62  아프리카 기타  768  718  90    206    908   2690
# 63     기타대륙   33    4   0      1     16     54
# 64     국적미상   33    4   0      1     16     54
# 65     교포소계    0    0   0      0  15526  15526
# 66       교포    0    0   0      0  15526  15526

# %% [markdown]
# #### 데이터 전처리

# %%
# 데이터 수와 타입
kto_201901.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   국적      67 non-null     object
#  1   관광      67 non-null     int64
#  2   상용      67 non-null     int64
#  3   공용      67 non-null     int64
#  4   유학/연수   67 non-null     int64
#  5   기타      67 non-null     int64
#  6   계       67 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 3.8+ KB

# %%
# 행과 열값 리턴
kto_201901.describe()
# Out:
#                  관광            상용           공용         유학/연수             기타  \
# count      67.00000     67.000000    67.000000     67.000000      67.000000
# mean    26396.80597    408.208955   132.507463    477.462687    5564.208955
# std    102954.04969   1416.040302   474.406339   2009.484800   17209.438418
# min         0.00000      0.000000     0.000000      0.000000      16.000000
# 25%       505.00000     14.500000     2.500000     17.500000     260.000000
# 50%      1304.00000     45.000000    14.000000     43.000000     912.000000
# 75%      8365.00000    176.500000    38.000000    182.000000    2824.500000
# max    765082.00000  10837.000000  2657.000000  14087.000000  125521.000000
#
#                    계
# count      67.000000
# mean    32979.194030
# std    122821.369969
# min        54.000000
# 25%       927.000000
# 50%      2695.000000
# 75%     14905.500000
# max    916950.000000

# %%
# 수치통계
kto_201901.describe()
# Out:
#                  관광            상용           공용         유학/연수             기타  \
# count      67.00000     67.000000    67.000000     67.000000      67.000000
# mean    26396.80597    408.208955   132.507463    477.462687    5564.208955
# std    102954.04969   1416.040302   474.406339   2009.484800   17209.438418
# min         0.00000      0.000000     0.000000      0.000000      16.000000
# 25%       505.00000     14.500000     2.500000     17.500000     260.000000
# 50%      1304.00000     45.000000    14.000000     43.000000     912.000000
# 75%      8365.00000    176.500000    38.000000    182.000000    2824.500000
# max    765082.00000  10837.000000  2657.000000  14087.000000  125521.000000
#
#                    계
# count      67.000000
# mean    32979.194030
# std    122821.369969
# min        54.000000
# 25%       927.000000
# 50%      2695.000000
# 75%     14905.500000
# max    916950.000000

# %%
# 각 컬럼 0 부분이 필터링 (체크)
condition = (kto_201901['관광'] == 0) | \
            (kto_201901['상용'] == 0) | \
            (kto_201901['공용'] == 0) | \
            (kto_201901['유학/연수'] == 0) | \
            (kto_201901['기타'] == 0)
            
kto_201901_zero = kto_201901[condition]
kto_201901_zero
# Out:
#         국적    관광   상용  공용  유학/연수     기타      계
# 4      마카오  2506    2   0     17     45   2570
# 20    이스라엘   727   12   0      9     57    805
# 22  우즈베키스탄  1958  561   0    407   2828   5754
# 38     스위스   613   18   0     19     97    747
# 45     그리스   481   17   4      0    273    775
# 46    포르투갈   416   14   0     13    121    564
# 51   크로아티아   226   12   0      3    250    491
# 54     폴란드   713   10   0     27    574   1324
# 59  대양주 기타   555    3   4      0     52    614
# 63    기타대륙    33    4   0      1     16     54
# 64    국적미상    33    4   0      1     16     54
# 65    교포소계     0    0   0      0  15526  15526
# 66      교포     0    0   0      0  15526  15526

# %%
# df에 기준년월 추가
kto_201901['기준년월'] = '2019-01'
kto_201901
# Out:
#          국적      관광     상용    공용  유학/연수      기타       계     기준년월
# 0      아시아주  765082  10837  1423  14087  125521  916950  2019-01
# 1        일본  198805   2233   127    785    4576  206526  2019-01
# 2        대만   86393     74    22    180    1285   87954  2019-01
# 3        홍콩   34653     59     2     90    1092   35896  2019-01
# 4       마카오    2506      2     0     17      45    2570  2019-01
# ..      ...     ...    ...   ...    ...     ...     ...      ...
# 62  아프리카 기타     768    718    90    206     908    2690  2019-01
# 63     기타대륙      33      4     0      1      16      54  2019-01
# 64     국적미상      33      4     0      1      16      54  2019-01
# 65     교포소계       0      0     0      0   15526   15526  2019-01
# 66       교포       0      0     0      0   15526   15526  2019-01
#
# [67 rows x 8 columns]

# %%
# 국적데이터만 67개 중
# unique()는 numpy.ndarray 변환
# 원래 67개, unique() 67개 (의미없음)
kto_201901['국적'].unique()
# Out:
# array(['아시아주', '일본', '대만', '홍콩', '마카오', '태국', '말레이시아', '필리핀', '인도네시아',
#        '싱가포르', '미얀마', '베트남', '인도', '스리랑카', '파키스탄', '방글라데시', '캄보디아', '몽골',
#        '중국', '이란', '이스라엘', '터키', '우즈베키스탄', '카자흐스탄', 'GCC', '아시아 기타', '미주',
#        '미국', '캐나다', '멕시코', '브라질', '미주 기타', '구주', '영국', '독일', '프랑스',
#        '네덜란드', '스웨덴', '스위스', '이탈리아', '덴마크', '노르웨이', '벨기에', '오스트리아', '스페인',
#        '그리스', '포르투갈', '핀란드', '아일랜드', '우크라이나', '러시아', '크로아티아', '루마니아',
#        '불가리아', '폴란드', '구주 기타', '대양주', '오스트레일리아', '뉴질랜드', '대양주 기타',
#        '아프리카주', '남아프리카공화국', '아프리카 기타', '기타대륙', '국적미상', '교포소계', '교포'],
#       dtype=object)

# %%
# 대륙 목록
contients_list = ['아시아주', '미주', '구주', '대양주', '아프리카주', '기타대륙', '교포소계']

contients_list
# Out:
# ['아시아주', '미주', '구주', '대양주', '아프리카주', '기타대륙', '교포소계']

# %%
kto_201901[kto_201901['국적'].isin(contients_list) == False]
# Out:
#           국적      관광    상용    공용  유학/연수     기타       계     기준년월
# 1         일본  198805  2233   127    785   4576  206526  2019-01
# 2         대만   86393    74    22    180   1285   87954  2019-01
# 3         홍콩   34653    59     2     90   1092   35896  2019-01
# 4        마카오    2506     2     0     17     45    2570  2019-01
# 5         태국   34004    37   199     96   6998   41334  2019-01
# 6      말레이시아   19043    95     7     99   2821   22065  2019-01
# 7        필리핀   14279   211   161    184  15638   30473  2019-01
# 8      인도네시아   14183   136    38    187   4298   18842  2019-01
# 9       싱가포르    8372    94     8     48   1333    9855  2019-01
# 10       미얀마    1304    10    31     67   3877    5289  2019-01
# 11       베트남   10739   763   110   1667   6904   20183  2019-01
# 12        인도    2318  2656    46    177   3474    8671  2019-01
# 13      스리랑카     157    54     5     28   1043    1287  2019-01
# 14      파키스탄     238   178    10    193    413    1032  2019-01
# 15     방글라데시     149   126    27     97    848    1247  2019-01
# 16      캄보디아     635    39    55     51   1915    2695  2019-01
# 17        몽골    8358    77   304    484    562    9785  2019-01
# 18        중국  320113  2993   138   8793  60777  392814  2019-01
# 19        이란      60    45    10     23     46     184  2019-01
# 20      이스라엘     727    12     0      9     57     805  2019-01
# 21        터키     792    13    32     36    912    1785  2019-01
# 22    우즈베키스탄    1958   561     0    407   2828    5754  2019-01
# 23     카자흐스탄    2185    24     7     92   1266    3574  2019-01
# 24       GCC    1550    37    14     72    103    1776  2019-01
# 25    아시아 기타    1561   308    70    205   2410    4554  2019-01
# 27        미국   42989   418  2578    229  16523   62737  2019-01
# 28       캐나다    8034    57    30     43   4296   12460  2019-01
# 29       멕시코    1282    11     7     38    515    1853  2019-01
# 30       브라질    1136    16     9     41    403    1605  2019-01
# 31     미주 기타    1541    24    33    128    540    2266  2019-01
# 33        영국    7982   175    17     41   1933   10148  2019-01
# 34        독일    4925   278    19    177   1451    6850  2019-01
# 35       프랑스    3773   297    48    288   1168    5574  2019-01
# 36      네덜란드    1592    47    16     77    537    2269  2019-01
# 37       스웨덴     844    29     6     18     85     982  2019-01
# 38       스위스     613    18     0     19     97     747  2019-01
# 39      이탈리아    1968    83    17     40    623    2731  2019-01
# 40       덴마크     520    21     6     16    188     751  2019-01
# 41      노르웨이     552    66     4     28    151     801  2019-01
# 42       벨기에     490    24     4     22    169     709  2019-01
# 43     오스트리아     544     8     2     13    209     776  2019-01
# 44       스페인    1010    36    15     52    255    1368  2019-01
# 45       그리스     481    17     4      0    273     775  2019-01
# 46      포르투갈     416    14     0     13    121     564  2019-01
# 47       핀란드     412    23     1     18    405     859  2019-01
# 48      아일랜드     392    15     1      2    185     595  2019-01
# 49     우크라이나     593    58     3     28   1580    2262  2019-01
# 50       러시아   17260   181    37    191   7525   25194  2019-01
# 51     크로아티아     226    12     0      3    250     491  2019-01
# 52      루마니아     412     8     4      3    445     872  2019-01
# 53      불가리아     154     1     1     10    265     431  2019-01
# 54       폴란드     713    10     0     27    574    1324  2019-01
# 55     구주 기타    1809    44    25     91    996    2965  2019-01
# 57   오스트레일리아   12795    93    17     34   1346   14285  2019-01
# 58      뉴질랜드    2029    20    17      5    654    2725  2019-01
# 59    대양주 기타     555     3     4      0     52     614  2019-01
# 61  남아프리카공화국     368     9     1      6    616    1000  2019-01
# 62   아프리카 기타     768   718    90    206    908    2690  2019-01
# 64      국적미상      33     4     0      1     16      54  2019-01
# 66        교포       0     0     0      0  15526   15526  2019-01

# %%
kto_201901_country = kto_201901[(kto_201901.국적.isin(contients_list) == False)]
# kto_201901_country.국적.unique()
kto_201901_country
# Out:
#           국적      관광    상용    공용  유학/연수     기타       계     기준년월
# 1         일본  198805  2233   127    785   4576  206526  2019-01
# 2         대만   86393    74    22    180   1285   87954  2019-01
# 3         홍콩   34653    59     2     90   1092   35896  2019-01
# 4        마카오    2506     2     0     17     45    2570  2019-01
# 5         태국   34004    37   199     96   6998   41334  2019-01
# 6      말레이시아   19043    95     7     99   2821   22065  2019-01
# 7        필리핀   14279   211   161    184  15638   30473  2019-01
# 8      인도네시아   14183   136    38    187   4298   18842  2019-01
# 9       싱가포르    8372    94     8     48   1333    9855  2019-01
# 10       미얀마    1304    10    31     67   3877    5289  2019-01
# 11       베트남   10739   763   110   1667   6904   20183  2019-01
# 12        인도    2318  2656    46    177   3474    8671  2019-01
# 13      스리랑카     157    54     5     28   1043    1287  2019-01
# 14      파키스탄     238   178    10    193    413    1032  2019-01
# 15     방글라데시     149   126    27     97    848    1247  2019-01
# 16      캄보디아     635    39    55     51   1915    2695  2019-01
# 17        몽골    8358    77   304    484    562    9785  2019-01
# 18        중국  320113  2993   138   8793  60777  392814  2019-01
# 19        이란      60    45    10     23     46     184  2019-01
# 20      이스라엘     727    12     0      9     57     805  2019-01
# 21        터키     792    13    32     36    912    1785  2019-01
# 22    우즈베키스탄    1958   561     0    407   2828    5754  2019-01
# 23     카자흐스탄    2185    24     7     92   1266    3574  2019-01
# 24       GCC    1550    37    14     72    103    1776  2019-01
# 25    아시아 기타    1561   308    70    205   2410    4554  2019-01
# 27        미국   42989   418  2578    229  16523   62737  2019-01
# 28       캐나다    8034    57    30     43   4296   12460  2019-01
# 29       멕시코    1282    11     7     38    515    1853  2019-01
# 30       브라질    1136    16     9     41    403    1605  2019-01
# 31     미주 기타    1541    24    33    128    540    2266  2019-01
# 33        영국    7982   175    17     41   1933   10148  2019-01
# 34        독일    4925   278    19    177   1451    6850  2019-01
# 35       프랑스    3773   297    48    288   1168    5574  2019-01
# 36      네덜란드    1592    47    16     77    537    2269  2019-01
# 37       스웨덴     844    29     6     18     85     982  2019-01
# 38       스위스     613    18     0     19     97     747  2019-01
# 39      이탈리아    1968    83    17     40    623    2731  2019-01
# 40       덴마크     520    21     6     16    188     751  2019-01
# 41      노르웨이     552    66     4     28    151     801  2019-01
# 42       벨기에     490    24     4     22    169     709  2019-01
# 43     오스트리아     544     8     2     13    209     776  2019-01
# 44       스페인    1010    36    15     52    255    1368  2019-01
# 45       그리스     481    17     4      0    273     775  2019-01
# 46      포르투갈     416    14     0     13    121     564  2019-01
# 47       핀란드     412    23     1     18    405     859  2019-01
# 48      아일랜드     392    15     1      2    185     595  2019-01
# 49     우크라이나     593    58     3     28   1580    2262  2019-01
# 50       러시아   17260   181    37    191   7525   25194  2019-01
# 51     크로아티아     226    12     0      3    250     491  2019-01
# 52      루마니아     412     8     4      3    445     872  2019-01
# 53      불가리아     154     1     1     10    265     431  2019-01
# 54       폴란드     713    10     0     27    574    1324  2019-01
# 55     구주 기타    1809    44    25     91    996    2965  2019-01
# 57   오스트레일리아   12795    93    17     34   1346   14285  2019-01
# 58      뉴질랜드    2029    20    17      5    654    2725  2019-01
# 59    대양주 기타     555     3     4      0     52     614  2019-01
# 61  남아프리카공화국     368     9     1      6    616    1000  2019-01
# 62   아프리카 기타     768   718    90    206    908    2690  2019-01
# 64      국적미상      33     4     0      1     16      54  2019-01
# 66        교포       0     0     0      0  15526   15526  2019-01

# %%
kto_201901_country.국적.unique()
# Out:
# array(['일본', '대만', '홍콩', '마카오', '태국', '말레이시아', '필리핀', '인도네시아', '싱가포르',
#        '미얀마', '베트남', '인도', '스리랑카', '파키스탄', '방글라데시', '캄보디아', '몽골', '중국',
#        '이란', '이스라엘', '터키', '우즈베키스탄', '카자흐스탄', 'GCC', '아시아 기타', '미국',
#        '캐나다', '멕시코', '브라질', '미주 기타', '영국', '독일', '프랑스', '네덜란드', '스웨덴',
#        '스위스', '이탈리아', '덴마크', '노르웨이', '벨기에', '오스트리아', '스페인', '그리스', '포르투갈',
#        '핀란드', '아일랜드', '우크라이나', '러시아', '크로아티아', '루마니아', '불가리아', '폴란드',
#        '구주 기타', '오스트레일리아', '뉴질랜드', '대양주 기타', '남아프리카공화국', '아프리카 기타',
#        '국적미상', '교포'], dtype=object)

# %%
# 인덱스 재설정
kto_201901_country_newindex = kto_201901_country.reset_index(drop = True)
kto_201901_country_newindex.tail()
# Out:
#           국적   관광   상용  공용  유학/연수     기타      계     기준년월
# 55    대양주 기타  555    3   4      0     52    614  2019-01
# 56  남아프리카공화국  368    9   1      6    616   1000  2019-01
# 57   아프리카 기타  768  718  90    206    908   2690  2019-01
# 58      국적미상   33    4   0      1     16     54  2019-01
# 59        교포    0    0   0      0  15526  15526  2019-01

# %%
# 대륙컬럼 다시 만들기
contients = ['아시아'] * 25 + ['아메리카'] * 5 + ['유럽'] * 23 + ['오세아니아'] * 3 + ['아프리카'] * 2 + ['기타'] + ['교포']

print(contients)
# Out:
# ['아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아메리카', '아메리카', '아메리카', '아메리카', '아메리카', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '오세아니아', '오세아니아', '오세아니아', '아프리카', '아프리카', '기타', '교포']

# %%
kto_201901_country_newindex['대륙'] = contients
kto_201901_country_newindex.head()
# Out:
#     국적      관광    상용   공용  유학/연수    기타       계     기준년월   대륙
# 0   일본  198805  2233  127    785  4576  206526  2019-01  아시아
# 1   대만   86393    74   22    180  1285   87954  2019-01  아시아
# 2   홍콩   34653    59    2     90  1092   35896  2019-01  아시아
# 3  마카오    2506     2    0     17    45    2570  2019-01  아시아
# 4   태국   34004    37  199     96  6998   41334  2019-01  아시아

# %%
kto_201901_country_newindex['대륙'] = contients
kto_201901_country_newindex.tail()
# Out:
#           국적   관광   상용  공용  유학/연수     기타      계     기준년월     대륙
# 55    대양주 기타  555    3   4      0     52    614  2019-01  오세아니아
# 56  남아프리카공화국  368    9   1      6    616   1000  2019-01   아프리카
# 57   아프리카 기타  768  718  90    206    908   2690  2019-01   아프리카
# 58      국적미상   33    4   0      1     16     54  2019-01     기타
# 59        교포    0    0   0      0  15526  15526  2019-01     교포

# %%
# 국적별 관광객 비율
# 관광, 상용, 공용, 유학/연수, 기타 중 관광
# kto_201901_country_newindex.관광 # 밑에랑 똑같음
kto_201901_country_newindex['관광객비율(%)'] = \
    round((kto_201901_country_newindex['관광'] / kto_201901_country_newindex['계']) * 100, 1) #소수점 첫째자리까지

kto_201901_country_newindex
# Out:
#           국적      관광    상용    공용  유학/연수     기타       계     기준년월     대륙  \
# 0         일본  198805  2233   127    785   4576  206526  2019-01    아시아
# 1         대만   86393    74    22    180   1285   87954  2019-01    아시아
# 2         홍콩   34653    59     2     90   1092   35896  2019-01    아시아
# 3        마카오    2506     2     0     17     45    2570  2019-01    아시아
# 4         태국   34004    37   199     96   6998   41334  2019-01    아시아
# 5      말레이시아   19043    95     7     99   2821   22065  2019-01    아시아
# 6        필리핀   14279   211   161    184  15638   30473  2019-01    아시아
# 7      인도네시아   14183   136    38    187   4298   18842  2019-01    아시아
# 8       싱가포르    8372    94     8     48   1333    9855  2019-01    아시아
# 9        미얀마    1304    10    31     67   3877    5289  2019-01    아시아
# 10       베트남   10739   763   110   1667   6904   20183  2019-01    아시아
# 11        인도    2318  2656    46    177   3474    8671  2019-01    아시아
# 12      스리랑카     157    54     5     28   1043    1287  2019-01    아시아
# 13      파키스탄     238   178    10    193    413    1032  2019-01    아시아
# 14     방글라데시     149   126    27     97    848    1247  2019-01    아시아
# 15      캄보디아     635    39    55     51   1915    2695  2019-01    아시아
# 16        몽골    8358    77   304    484    562    9785  2019-01    아시아
# 17        중국  320113  2993   138   8793  60777  392814  2019-01    아시아
# 18        이란      60    45    10     23     46     184  2019-01    아시아
# 19      이스라엘     727    12     0      9     57     805  2019-01    아시아
# 20        터키     792    13    32     36    912    1785  2019-01    아시아
# 21    우즈베키스탄    1958   561     0    407   2828    5754  2019-01    아시아
# 22     카자흐스탄    2185    24     7     92   1266    3574  2019-01    아시아
# 23       GCC    1550    37    14     72    103    1776  2019-01    아시아
# 24    아시아 기타    1561   308    70    205   2410    4554  2019-01    아시아
# 25        미국   42989   418  2578    229  16523   62737  2019-01   아메리카
# 26       캐나다    8034    57    30     43   4296   12460  2019-01   아메리카
# 27       멕시코    1282    11     7     38    515    1853  2019-01   아메리카
# 28       브라질    1136    16     9     41    403    1605  2019-01   아메리카
# 29     미주 기타    1541    24    33    128    540    2266  2019-01   아메리카
# 30        영국    7982   175    17     41   1933   10148  2019-01     유럽
# 31        독일    4925   278    19    177   1451    6850  2019-01     유럽
# 32       프랑스    3773   297    48    288   1168    5574  2019-01     유럽
# 33      네덜란드    1592    47    16     77    537    2269  2019-01     유럽
# 34       스웨덴     844    29     6     18     85     982  2019-01     유럽
# 35       스위스     613    18     0     19     97     747  2019-01     유럽
# 36      이탈리아    1968    83    17     40    623    2731  2019-01     유럽
# 37       덴마크     520    21     6     16    188     751  2019-01     유럽
# 38      노르웨이     552    66     4     28    151     801  2019-01     유럽
# 39       벨기에     490    24     4     22    169     709  2019-01     유럽
# 40     오스트리아     544     8     2     13    209     776  2019-01     유럽
# 41       스페인    1010    36    15     52    255    1368  2019-01     유럽
# 42       그리스     481    17     4      0    273     775  2019-01     유럽
# 43      포르투갈     416    14     0     13    121     564  2019-01     유럽
# 44       핀란드     412    23     1     18    405     859  2019-01     유럽
# 45      아일랜드     392    15     1      2    185     595  2019-01     유럽
# 46     우크라이나     593    58     3     28   1580    2262  2019-01     유럽
# 47       러시아   17260   181    37    191   7525   25194  2019-01     유럽
# 48     크로아티아     226    12     0      3    250     491  2019-01     유럽
# 49      루마니아     412     8     4      3    445     872  2019-01     유럽
# 50      불가리아     154     1     1     10    265     431  2019-01     유럽
# 51       폴란드     713    10     0     27    574    1324  2019-01     유럽
# 52     구주 기타    1809    44    25     91    996    2965  2019-01     유럽
# 53   오스트레일리아   12795    93    17     34   1346   14285  2019-01  오세아니아
# 54      뉴질랜드    2029    20    17      5    654    2725  2019-01  오세아니아
# 55    대양주 기타     555     3     4      0     52     614  2019-01  오세아니아
# 56  남아프리카공화국     368     9     1      6    616    1000  2019-01   아프리카
# 57   아프리카 기타     768   718    90    206    908    2690  2019-01   아프리카
# 58      국적미상      33     4     0      1     16      54  2019-01     기타
# 59        교포       0     0     0      0  15526   15526  2019-01     교포
#
#     관광객비율(%)
# 0       96.3
# 1       98.2
# 2       96.5
# 3       97.5
# 4       82.3
# 5       86.3
# 6       46.9
# 7       75.3
# 8       85.0
# 9       24.7
# 10      53.2
# 11      26.7
# 12      12.2
# 13      23.1
# 14      11.9
# 15      23.6
# 16      85.4
# 17      81.5
# 18      32.6
# 19      90.3
# 20      44.4
# 21      34.0
# 22      61.1
# 23      87.3
# 24      34.3
# 25      68.5
# 26      64.5
# 27      69.2
# 28      70.8
# 29      68.0
# 30      78.7
# 31      71.9
# 32      67.7
# 33      70.2
# 34      85.9
# 35      82.1
# 36      72.1
# 37      69.2
# 38      68.9
# 39      69.1
# 40      70.1
# 41      73.8
# 42      62.1
# 43      73.8
# 44      48.0
# 45      65.9
# 46      26.2
# 47      68.5
# 48      46.0
# 49      47.2
# 50      35.7
# 51      53.9
# 52      61.0
# 53      89.6
# 54      74.5
# 55      90.4
# 56      36.8
# 57      28.6
# 58      61.1
# 59       0.0

# %%
# 분석 - 관광객 비율이 높은 국가와 낮은 국가
kto_201901_country_newindex.sort_values(by = '관광객비율(%)', ascending=False).head()
# Out:
#         국적      관광    상용   공용  유학/연수    기타       계     기준년월     대륙  관광객비율(%)
# 1       대만   86393    74   22    180  1285   87954  2019-01    아시아      98.2
# 3      마카오    2506     2    0     17    45    2570  2019-01    아시아      97.5
# 2       홍콩   34653    59    2     90  1092   35896  2019-01    아시아      96.5
# 0       일본  198805  2233  127    785  4576  206526  2019-01    아시아      96.3
# 55  대양주 기타     555     3    4      0    52     614  2019-01  오세아니아      90.4

# %%
# 대륙별 관광객 비율
kto_201901_country_newindex.pivot_table(values='관광객비율(%)', index='대륙', sort = False) # , aggfunc = 'mean',  sort = False는 대륙순서대로
# Out:
#         관광객비율(%)
# 대륙
# 아시아    59.624000
# 아메리카   68.200000
# 유럽     63.826087
# 오세아니아  84.833333
# 아프리카   32.700000
# 기타     61.100000
# 교포      0.000000

# %%
# 중국 관광객만
kto_201901_country_newindex[(kto_201901_country_newindex['국적'] == '중국')]
# Out:
#     국적      관광    상용   공용  유학/연수     기타       계     기준년월   대륙  관광객비율(%)
# 17  중국  320113  2993  138   8793  60777  392814  2019-01  아시아      81.5

# %%
# 전체 외국인 관광객 수
tourist_sum = sum(kto_201901_country_newindex['관광'])
tourist_sum
# Out:
# 884293

# %%
# 전체 비율

kto_201901_country_newindex['전체비율(%)'] = \
    round((kto_201901_country_newindex['관광'] / tourist_sum ) * 100, 1)
kto_201901_country_newindex.head()
# Out:
#     국적      관광    상용   공용  유학/연수    기타       계     기준년월   대륙  관광객비율(%)  \
# 0   일본  198805  2233  127    785  4576  206526  2019-01  아시아      96.3
# 1   대만   86393    74   22    180  1285   87954  2019-01  아시아      98.2
# 2   홍콩   34653    59    2     90  1092   35896  2019-01  아시아      96.5
# 3  마카오    2506     2    0     17    45    2570  2019-01  아시아      97.5
# 4   태국   34004    37  199     96  6998   41334  2019-01  아시아      82.3
#
#    전체비율(%)
# 0     22.5
# 1      9.8
# 2      3.9
# 3      0.3
# 4      3.8

# %%
# 관광객 전체비율이 높은 나라 내림차순 정렬
kto_201901_country_newindex.sort_values('전체비율(%)', ascending=False).head() # ascending=False 내림차순
# Out:
#     국적      관광    상용    공용  유학/연수     기타       계     기준년월    대륙  관광객비율(%)  \
# 17  중국  320113  2993   138   8793  60777  392814  2019-01   아시아      81.5
# 0   일본  198805  2233   127    785   4576  206526  2019-01   아시아      96.3
# 1   대만   86393    74    22    180   1285   87954  2019-01   아시아      98.2
# 25  미국   42989   418  2578    229  16523   62737  2019-01  아메리카      68.5
# 2   홍콩   34653    59     2     90   1092   35896  2019-01   아시아      96.5
#
#     전체비율(%)
# 17     36.2
# 0      22.5
# 1       9.8
# 25      4.9
# 2       3.9

# %% [markdown]
# ##### 위 내용을 자동화할 수 있는 함수 만들기
#
# 125개 엑셀파일 전처리

# %%
# 엑셀 파일 데이터프레임으로 재정리 함수

def create_kto_data(yyyy, mm):  # 년월 받아서 엑셀파일 오픈
    
    # 1. 엑셀파일 이름과 경로를 지정
    file_path = f'./data/kto_{yyyy+mm}.xlsx'
    # print(file_path)
    
    # 2. 엑셀파일 불러오기
    df = pd.read_excel(file_path, header=1, usecols='A:G', skipfooter=4)
    
    # 3. 기준년월 컬럼 추가
    df['기준년월'] = f'{yyyy}-{mm}'
    
    # 4. 국적 컬럼에 대륙 제거 국가만 남기기
    contients_list = ['아시아주', '미주', '구주', '대양주', '아프리카주', '기타대륙', '교포소계']
    condition = df['국적'].isin(contients_list) == False
    df_country = df[condition].reset_index(drop = True)
    
    # 5. 대륙 컬럼을 추가
    contients = ['아시아'] * 25 + ['아메리카'] * 5 + ['유럽'] * 23 + ['오세아니아'] * 3 + ['아프리카'] * 2 + ['기타대륙'] + ['교포']
    
    df_country['대륙'] = contients
    
    # 6. 국가별 관광객비율(%) 컬럼추가
    df_country['관광객비율(%)'] = round((df_country['관광'] / df_country['계']) * 100, 1)
    
    # 7. 전체비율(%) 추가
    tourist_sum = sum(df_country['관광'])
    df_country['전체비율(%)'] = round((df_country['관광'] / tourist_sum ) * 100, 1)
    
    # 8. 결과 출력
    return df_country

create_kto_data('2020','05')
# Out:
#           국적    관광   상용   공용  유학/연수    기타     계     기준년월     대륙  관광객비율(%)  \
# 0         일본    45  105    3     41   219   413  2020-05    아시아      10.9
# 1         대만    31    8    3     33   114   189  2020-05    아시아      16.4
# 2         홍콩     6    5    0      2    11    24  2020-05    아시아      25.0
# 3        마카오     0    0    0      1     0     1  2020-05    아시아       0.0
# 4         태국    25    7    0     13   150   195  2020-05    아시아      12.8
# 5      말레이시아     2    8    0      8    72    90  2020-05    아시아       2.2
# 6        필리핀   725    1   12      4   797  1539  2020-05    아시아      47.1
# 7      인도네시아   581    3    5      9  1157  1755  2020-05    아시아      33.1
# 8       싱가포르     6   10    0      3    30    49  2020-05    아시아      12.2
# 9        미얀마   178    1    0      6   516   701  2020-05    아시아      25.4
# 10       베트남    70    1    1    720   589  1381  2020-05    아시아       5.1
# 11        인도    95   15    0      3   302   415  2020-05    아시아      22.9
# 12      스리랑카    39    1    0      1   401   442  2020-05    아시아       8.8
# 13      파키스탄     0   17    1     44   153   215  2020-05    아시아       0.0
# 14     방글라데시     0    2    0     21   149   172  2020-05    아시아       0.0
# 15      캄보디아     4    2    0      1   351   358  2020-05    아시아       1.1
# 16        몽골     0    1    2     30    45    78  2020-05    아시아       0.0
# 17        중국   179   70    2   1189  3684  5124  2020-05    아시아       3.5
# 18        이란     1    0    2      2     3     8  2020-05    아시아      12.5
# 19      이스라엘     0    2    1      1     0     4  2020-05    아시아       0.0
# 20        터키     4    4    1      1    16    26  2020-05    아시아      15.4
# 21    우즈베키스탄     0    0    0      4     6    10  2020-05    아시아       0.0
# 22     카자흐스탄     8    1    0      2    15    26  2020-05    아시아      30.8
# 23       GCC     1    0    1      2    11    15  2020-05    아시아       6.7
# 24    아시아 기타     8    5    3      5    51    72  2020-05    아시아      11.1
# 25        미국  2996   33  186      9  5511  8735  2020-05   아메리카      34.3
# 26       캐나다    58    7    1      1   628   695  2020-05   아메리카       8.3
# 27       멕시코    20    1    0      0    48    69  2020-05   아메리카      29.0
# 28       브라질     3    3    0      0    47    53  2020-05   아메리카       5.7
# 29     미주 기타     2    0    6      3    59    70  2020-05   아메리카       2.9
# 30        영국   205   11    1      3   154   374  2020-05     유럽      54.8
# 31        독일    12   27    3      2  1710  1754  2020-05     유럽       0.7
# 32       프랑스    47   16    0      4    90   157  2020-05     유럽      29.9
# 33      네덜란드     2    5    2      1   683   693  2020-05     유럽       0.3
# 34       스웨덴     3    1    0      0    23    27  2020-05     유럽      11.1
# 35       스위스     0    0    0      5    23    28  2020-05     유럽       0.0
# 36      이탈리아    10   12    1      0   156   179  2020-05     유럽       5.6
# 37       덴마크     9    2    0      0    28    39  2020-05     유럽      23.1
# 38      노르웨이     2    4    0      0    49    55  2020-05     유럽       3.6
# 39       벨기에     1    3    0      0   175   179  2020-05     유럽       0.6
# 40     오스트리아     0    1    0      0   108   109  2020-05     유럽       0.0
# 41       스페인    16    5    2      2    42    67  2020-05     유럽      23.9
# 42       그리스    80    6    0      0    79   165  2020-05     유럽      48.5
# 43      포르투갈     2    0    0      1   161   164  2020-05     유럽       1.2
# 44       핀란드     0    3    0      1    51    55  2020-05     유럽       0.0
# 45      아일랜드     5    1    0      1     9    16  2020-05     유럽      31.2
# 46     우크라이나   265    6    1      2   157   431  2020-05     유럽      61.5
# 47       러시아    67    6    0      3  1617  1693  2020-05     유럽       4.0
# 48     크로아티아   147    1    0      0    46   194  2020-05     유럽      75.8
# 49      루마니아    34    1    0      0    58    93  2020-05     유럽      36.6
# 50      불가리아    13    0    0      0    31    44  2020-05     유럽      29.5
# 51       폴란드    40    1    1      0    98   140  2020-05     유럽      28.6
# 52     구주 기타    24    4    3      1   113   145  2020-05     유럽      16.6
# 53   오스트레일리아    30    5    0      0   102   137  2020-05  오세아니아      21.9
# 54      뉴질랜드     4    0    2      1    33    40  2020-05  오세아니아      10.0
# 55    대양주 기타     1    0    1      0     3     5  2020-05  오세아니아      20.0
# 56  남아프리카공화국     1    0    3      0    25    29  2020-05   아프리카       3.4
# 57   아프리카 기타     3    1    3      6   118   131  2020-05   아프리카       2.3
# 58      국적미상     1    0    0      0     3     4  2020-05   기타대륙      25.0
# 59        교포     0    0    0      0   790   790  2020-05     교포       0.0
#
#     전체비율(%)
# 0       0.7
# 1       0.5
# 2       0.1
# 3       0.0
# 4       0.4
# 5       0.0
# 6      11.9
# 7       9.5
# 8       0.1
# 9       2.9
# 10      1.1
# 11      1.6
# 12      0.6
# 13      0.0
# 14      0.0
# 15      0.1
# 16      0.0
# 17      2.9
# 18      0.0
# 19      0.0
# 20      0.1
# 21      0.0
# 22      0.1
# 23      0.0
# 24      0.1
# 25     49.0
# 26      0.9
# 27      0.3
# 28      0.0
# 29      0.0
# 30      3.4
# 31      0.2
# 32      0.8
# 33      0.0
# 34      0.0
# 35      0.0
# 36      0.2
# 37      0.1
# 38      0.0
# 39      0.0
# 40      0.0
# 41      0.3
# 42      1.3
# 43      0.0
# 44      0.0
# 45      0.1
# 46      4.3
# 47      1.1
# 48      2.4
# 49      0.6
# 50      0.2
# 51      0.7
# 52      0.4
# 53      0.5
# 54      0.1
# 55      0.0
# 56      0.0
# 57      0.0
# 58      0.0
# 59      0.0

# %% [markdown]
# ##### 반복문으로 125개 엑셀 하나로 합치기

# %%
# kto_yyyymm.xlxs

df = pd.DataFrame()
temps = []

for yyyy in range(2010, 2021): # 2020년까지니깐 +1 -> 2021을 넣어줘야 함
    for mm in range(1, 13):
        mm_str = str(mm).zfill(2)
        yyyymm = f'{yyyy}{mm_str}'
        if(yyyymm == '202006'): break
        temp = create_kto_data(str(yyyy), mm_str)
        temps.append(temp)

        # print(yyyymm, temp.shape, sep='|')

print(len(temps))
df = pd.concat(temps)
# Out:
# 125

# %%
df = df.reset_index(drop=True)
df.tail()
# Out:
#             국적  관광  상용  공용  유학/연수   기타    계     기준년월     대륙  관광객비율(%)  전체비율(%)
# 7495    대양주 기타   1   0   1      0    3    5  2020-05  오세아니아      20.0      0.0
# 7496  남아프리카공화국   1   0   3      0   25   29  2020-05   아프리카       3.4      0.0
# 7497   아프리카 기타   3   1   3      6  118  131  2020-05   아프리카       2.3      0.0
# 7498      국적미상   1   0   0      0    3    4  2020-05   기타대륙      25.0      0.0
# 7499        교포   0   0   0      0  790  790  2020-05     교포       0.0      0.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7500 entries, 0 to 7499
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   국적        7500 non-null   object
#  1   관광        7500 non-null   int64
#  2   상용        7500 non-null   int64
#  3   공용        7500 non-null   int64
#  4   유학/연수     7500 non-null   int64
#  5   기타        7500 non-null   int64
#  6   계         7500 non-null   int64
#  7   기준년월      7500 non-null   object
#  8   대륙        7500 non-null   object
#  9   관광객비율(%)  7500 non-null   float64
#  10  전체비율(%)   7500 non-null   float64
# dtypes: float64(2), int64(6), object(3)
# memory usage: 644.7+ KB

# %%
# 최종 결과 저장
df.to_excel('./result/kto_total.xlsx', index=False)

# %% [markdown]
# #### 나라별로 엑셀파일 만들기
#
# ##### 60개국 나라별 엑셀 만들기

# %%
# 7500 row 데이터 나라별
df_china = df[(df['국적'] == '중국')]
df_china
# Out:
#       국적      관광     상용   공용  유학/연수     기타       계     기준년월   대륙  관광객비율(%)  \
# 17    중국   40425  11930   55   2751  36091   91252  2010-01  아시아      44.3
# 77    중국   60590   7907   68  29546  42460  140571  2010-02  아시아      43.1
# 137   중국   50330  13549  174  14924  62480  141457  2010-03  아시아      35.6
# 197   중국   84252  13306  212   2199  47711  147680  2010-04  아시아      57.1
# 257   중국   89056  12325  360   2931  49394  154066  2010-05  아시아      57.8
# ...   ..     ...    ...  ...    ...    ...     ...      ...  ...       ...
# 7217  중국  393336   2813   99  10433  75000  481681  2020-01  아시아      81.7
# 7277  중국   49520    715   11  20753  33087  104086  2020-02  아시아      47.6
# 7337  중국    5040    115    2   7388   4050   16595  2020-03  아시아      30.4
# 7397  중국     522     71    0   1112   2230    3935  2020-04  아시아      13.3
# 7457  중국     179     70    2   1189   3684    5124  2020-05  아시아       3.5
#
#       전체비율(%)
# 17       10.1
# 77       13.6
# 137       9.2
# 197      15.5
# 257      17.0
# ...       ...
# 7217     38.2
# 7277      9.8
# 7337     16.0
# 7397     10.2
# 7457      2.9
#
# [125 rows x 11 columns]

# %%
df_china.to_excel('./result/kto_중국.xlsx', index=False)

# %%
# 국적 리스트
country_list = df['국적'].unique()
country_list
# Out:
# array(['일본', '대만', '홍콩', '마카오', '태국', '말레이시아', '필리핀', '인도네시아', '싱가포르',
#        '미얀마', '베트남', '인도', '스리랑카', '파키스탄', '방글라데시', '캄보디아', '몽골', '중국',
#        '이란', '이스라엘', '터키', '우즈베키스탄', '카자흐스탄', 'GCC', '아시아 기타', '미국',
#        '캐나다', '멕시코', '브라질', '미주 기타', '영국', '독일', '프랑스', '네덜란드', '스웨덴',
#        '스위스', '이탈리아', '덴마크', '노르웨이', '벨기에', '오스트리아', '스페인', '그리스', '포르투갈',
#        '핀란드', '아일랜드', '우크라이나', '러시아', '크로아티아', '루마니아', '불가리아', '폴란드',
#        '구주 기타', '오스트레일리아', '뉴질랜드', '대양주 기타', '남아프리카공화국', '아프리카 기타',
#        '국적미상', '교포'], dtype=object)

# %%
# 60개의 엑셀 파일
for country in country_list:
    # 국적 필터링
    df_filter = df[(df['국적'] == country)]
    df_filter.to_excel(f'./result/kto_{country}.xlsx', index=False)

# %% [markdown]
# #### 결론
#
# ##### 3개월 데이터분석 프로젝트 -> 1.5개월 이상이 데이터 전처리하는데 소요 - 정합성, 오류, 결측치 확인
# ##### Next Step -> 분석, 시각화

# %% [markdown]
# ##### 시각화 (Visualization)
# 예전엔 차트, 분석 차트화

# %%
# 중국 관광객
df_china
# Out:
#       국적      관광     상용   공용  유학/연수     기타       계     기준년월   대륙  관광객비율(%)  \
# 17    중국   40425  11930   55   2751  36091   91252  2010-01  아시아      44.3
# 77    중국   60590   7907   68  29546  42460  140571  2010-02  아시아      43.1
# 137   중국   50330  13549  174  14924  62480  141457  2010-03  아시아      35.6
# 197   중국   84252  13306  212   2199  47711  147680  2010-04  아시아      57.1
# 257   중국   89056  12325  360   2931  49394  154066  2010-05  아시아      57.8
# ...   ..     ...    ...  ...    ...    ...     ...      ...  ...       ...
# 7217  중국  393336   2813   99  10433  75000  481681  2020-01  아시아      81.7
# 7277  중국   49520    715   11  20753  33087  104086  2020-02  아시아      47.6
# 7337  중국    5040    115    2   7388   4050   16595  2020-03  아시아      30.4
# 7397  중국     522     71    0   1112   2230    3935  2020-04  아시아      13.3
# 7457  중국     179     70    2   1189   3684    5124  2020-05  아시아       3.5
#
#       전체비율(%)
# 17       10.1
# 77       13.6
# 137       9.2
# 197      15.5
# 257      17.0
# ...       ...
# 7217     38.2
# 7277      9.8
# 7337     16.0
# 7397     10.2
# 7457      2.9
#
# [125 rows x 11 columns]

# %% [markdown]
# ##### Matplotlib 사용
# - Matplotlib은 한글 지원이 자동으로 되지 않기 때문에 추가 설정이 필요함
# - Seaborn 추가

# %%
import matplotlib
# from matplotlib import pyplot as plt
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc, rcParams
import seaborn as sns

font_path = 'C:/Windows/Fonts/NanumGothic.ttf'
font = font_manager.FontProperties(fname=font_path).get_name() # 나눔고딕, NanumGothic
rc('font', family=font)
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
# 중국 관광객 데이터 로드
df_filter = pd.read_excel('./result/kto_중국.xlsx')
df_filter
# Out:
#      국적      관광     상용   공용  유학/연수     기타       계     기준년월   대륙  관광객비율(%)  \
# 0    중국   40425  11930   55   2751  36091   91252  2010-01  아시아      44.3
# 1    중국   60590   7907   68  29546  42460  140571  2010-02  아시아      43.1
# 2    중국   50330  13549  174  14924  62480  141457  2010-03  아시아      35.6
# 3    중국   84252  13306  212   2199  47711  147680  2010-04  아시아      57.1
# 4    중국   89056  12325  360   2931  49394  154066  2010-05  아시아      57.8
# ..   ..     ...    ...  ...    ...    ...     ...      ...  ...       ...
# 120  중국  393336   2813   99  10433  75000  481681  2020-01  아시아      81.7
# 121  중국   49520    715   11  20753  33087  104086  2020-02  아시아      47.6
# 122  중국    5040    115    2   7388   4050   16595  2020-03  아시아      30.4
# 123  중국     522     71    0   1112   2230    3935  2020-04  아시아      13.3
# 124  중국     179     70    2   1189   3684    5124  2020-05  아시아       3.5
#
#      전체비율(%)
# 0       10.1
# 1       13.6
# 2        9.2
# 3       15.5
# 4       17.0
# ..       ...
# 120     38.2
# 121      9.8
# 122     16.0
# 123     10.2
# 124      2.9
#
# [125 rows x 11 columns]

# %%
plt.figure(figsize=(12, 4))
plt.plot(df_filter['기준년월'], df_filter['관광'], scalex=True)

plt.title('중국 관광객 추이')
plt.xlabel('기준년월')
plt.ylabel('관광객 수')

# plt.xticks(rotation=90)
plt.xticks(['2010-01', '2011-01', '2012-01', '2013-01', '2014-01', '2015-01', '2016-01', '2017-01', '2018-01', '2019-01', '2020-01'])

plt.show()

# %%
# 중국, 일본, 미국, 홍콩, 대만 5개국 라인 차트 생략

# %%
# 히트맵
df['년도'] = df['기준년월'].str.slice(0, 4)
df['월'] = df['기준년월'].str.slice(5, 7)
df
# Out:
#             국적      관광    상용  공용  유학/연수    기타       계     기준년월     대륙  \
# 0           일본  202825  1750  89    549  3971  209184  2010-01    아시아
# 1           대만   35788    41  17     37   516   36399  2010-01    아시아
# 2           홍콩   13874    55   0     21   595   14545  2010-01    아시아
# 3          마카오     554     0   0      0     0     554  2010-01    아시아
# 4           태국   13374    39  13     53  4335   17814  2010-01    아시아
# ...        ...     ...   ...  ..    ...   ...     ...      ...    ...
# 7495    대양주 기타       1     0   1      0     3       5  2020-05  오세아니아
# 7496  남아프리카공화국       1     0   3      0    25      29  2020-05   아프리카
# 7497   아프리카 기타       3     1   3      6   118     131  2020-05   아프리카
# 7498      국적미상       1     0   0      0     3       4  2020-05   기타대륙
# 7499        교포       0     0   0      0   790     790  2020-05     교포
#
#       관광객비율(%)  전체비율(%)    년도   월
# 0         97.0     50.6  2010  01
# 1         98.3      8.9  2010  01
# 2         95.4      3.5  2010  01
# 3        100.0      0.1  2010  01
# 4         75.1      3.3  2010  01
# ...        ...      ...   ...  ..
# 7495      20.0      0.0  2020  05
# 7496       3.4      0.0  2020  05
# 7497       2.3      0.0  2020  05
# 7498      25.0      0.0  2020  05
# 7499       0.0      0.0  2020  05
#
# [7500 rows x 13 columns]

# %%
df_china = df[(df['국적'] == '중국')]
df_china
# Out:
#       국적      관광     상용   공용  유학/연수     기타       계     기준년월   대륙  관광객비율(%)  \
# 17    중국   40425  11930   55   2751  36091   91252  2010-01  아시아      44.3
# 77    중국   60590   7907   68  29546  42460  140571  2010-02  아시아      43.1
# 137   중국   50330  13549  174  14924  62480  141457  2010-03  아시아      35.6
# 197   중국   84252  13306  212   2199  47711  147680  2010-04  아시아      57.1
# 257   중국   89056  12325  360   2931  49394  154066  2010-05  아시아      57.8
# ...   ..     ...    ...  ...    ...    ...     ...      ...  ...       ...
# 7217  중국  393336   2813   99  10433  75000  481681  2020-01  아시아      81.7
# 7277  중국   49520    715   11  20753  33087  104086  2020-02  아시아      47.6
# 7337  중국    5040    115    2   7388   4050   16595  2020-03  아시아      30.4
# 7397  중국     522     71    0   1112   2230    3935  2020-04  아시아      13.3
# 7457  중국     179     70    2   1189   3684    5124  2020-05  아시아       3.5
#
#       전체비율(%)    년도   월
# 17       10.1  2010  01
# 77       13.6  2010  02
# 137       9.2  2010  03
# 197      15.5  2010  04
# 257      17.0  2010  05
# ...       ...   ...  ..
# 7217     38.2  2020  01
# 7277      9.8  2020  02
# 7337     16.0  2020  03
# 7397     10.2  2020  04
# 7457      2.9  2020  05
#
# [125 rows x 13 columns]

# %%
# pivot
df_pivot = df_china.pivot_table(values='관광', index='년도', columns='월')
df_pivot
# Out:
# 월           01        02        03        04        05        06        07  \
# 년도
# 2010   40425.0   60590.0   50330.0   84252.0   89056.0   87080.0  122432.0
# 2011   55070.0   53863.0   72003.0   86397.0   85668.0  108060.0  170524.0
# 2012  106606.0   74895.0  110965.0  166843.0  154841.0  179074.0  258907.0
# 2013  148118.0  169395.0  182850.0  250549.0  196306.0  280319.0  417991.0
# 2014  230706.0  219533.0  313400.0  429419.0  410971.0  429991.0  540683.0
# 2015  327225.0  413096.0  386386.0  536428.0  517154.0  223101.0  172075.0
# 2016  456636.0  424232.0  500018.0  601460.0  614636.0  671493.0  823016.0
# 2017  489256.0  458952.0  263788.0  158784.0  172527.0  181507.0  207099.0
# 2018  236825.0  237075.0  281020.0  283533.0  284317.0  303405.0  332657.0
# 2019  320113.0  324291.0  369165.0  410542.0  413949.0  395196.0  439699.0
# 2020  393336.0   49520.0    5040.0     522.0     179.0       NaN       NaN
#
# 월           08        09        10        11        12
# 년도
# 2010  142180.0   93545.0  107237.0   75686.0   58987.0
# 2011  178937.0  144704.0  141824.0  113856.0  101605.0
# 2012  268988.0  203857.0  204866.0  155503.0  148320.0
# 2013  472005.0  353359.0  249850.0  208175.0  210950.0
# 2014  588181.0  423133.0  459708.0  381118.0  345957.0
# 2015  372990.0  453670.0  518651.0  409635.0  381722.0
# 2016  747818.0  611538.0  588561.0  452082.0  456882.0
# 2017  226153.0  229172.0  244541.0  223743.0  260983.0
# 2018  360982.0  326438.0  382922.0  327664.0  345135.0
# 2019  451570.0  432018.0  476460.0  426849.0  433577.0
# 2020       NaN       NaN       NaN       NaN       NaN

# %%
# 히트맵 출력
plt.figure(figsize=(16, 10))

sns.heatmap(df_pivot, annot=True, fmt='.0f', cmap='rocket_r')

plt.title('중국 관광객 히트맵')

plt.show()

# %% [markdown]
# ##### 히트맵 결과 해석
# - 여름(7, 8월)에 중국 관광객이 가장 많음
# - 여름 > 봄, 가을 > 겨울
# - 2015년 7월, 2017년 4~6월, 2020년도 2월~ 관광객 급격하게 줄었음
# - 뉴스 검색을 통해서 관광객 감소 이유 찾음
